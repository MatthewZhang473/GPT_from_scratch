# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# os.chdir('/content/drive/MyDrive')
# !git clone https://github.com/MatthewZhang473/GPT_from_scratch.git
# Out:
# Cloning into 'GPT_from_scratch'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 427.83 KiB | 2.61 MiB/s, done.

# %%
import os
os.chdir('/content/drive/MyDrive/GPT_from_scratch')
# !ls
# Out:
# checkpoints  gpt-dev.ipynb  gpt.py  input.txt  Readme.md  train_gpt.ipynb

# %%
# !python gpt.py
# Out:
# total params = 10.79M
# step 0: train loss 4.2846, val loss 4.2820
# step 500: train loss 1.8895, val loss 2.0023
# step 1000: train loss 1.5368, val loss 1.7224
# step 1500: train loss 1.3935, val loss 1.6030
# step 2000: train loss 1.3080, val loss 1.5440
# step 2500: train loss 1.2490, val loss 1.5109
# step 3000: train loss 1.2003, val loss 1.4913
# step 3500: train loss 1.1582, val loss 1.4782
# step 4000: train loss 1.1208, val loss 1.4790
# step 4500: train loss 1.0832, val loss 1.4719
# Loaded model from checkpoints/model_10.79M.pt
#
# Had you the drunkat hath winding brought,
# Not your ancient-boding shaffolks;
# But so 'lender, I'll find out to drew his.'
# If the longer than I may in dream,
# And till not what wy guest thou art flight,
# Explusiness in Decline, helmly de with blows:
# Sin York, Thomas Greently, then, I grieve thee,
# The prince, ere for two redeep less allowed
# Her doth thee from that eyes the perpetual sea
# ...
